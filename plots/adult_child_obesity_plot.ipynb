# %%
corr_df = compute_country_corr(adult_child_df)

corr_sample = corr_df.sample(20, random_state=42)   # pick 20 random countries
corr_matrix = corr_sample.set_index("Country")[["Correlation"]]

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Adult and Child Obesity (Sample of 20 Countries)")
plt.tight_layout()
plt.savefig('../Output/correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# <img src="../assets/adult_child_obesity_plot.png" width=auto>

# %%
cols = ['AdultObesity','ChildObesity','Overweight_U5','Wasting_U5','Stunting_U5','Sugar']
corr_sugar = sugar_corr_df[cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_sugar, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap: Sugar vs Obesity vs U5 Indicators (2019)")
plt.show()

# %% [markdown]
# <img src="../assets/correlation_heapmap_sugar_obesity.png" width=auto>

# %%
import numpy as np

df = adult_child_df.dropna(subset=['AdultObesity','ChildObesity'])

plt.figure(figsize=(6,4))
sns.regplot(data=df, x="ChildObesity", y="AdultObesity")
plt.title("Adult Obesity vs Child Obesity (Multi-Year)")
plt.show()

# %% [markdown]
# <img src="../assets/adult_obesity_vs_child_obesity.png" width=auto>

# %%
df = sugar_corr_df.dropna(subset=['Sugar','AdultObesity'])

plt.figure(figsize=(6,4))
sns.regplot(data=df, x="Sugar", y="AdultObesity")
plt.title("Adult Obesity vs Sugar Availability (2019)")
plt.show()

# %% [markdown]
# <img src="../assets/adult_sugar.png" width=auto>

# %%
df = sugar_corr_df.dropna(subset=['Sugar','ChildObesity'])

plt.figure(figsize=(6,4))
sns.regplot(data=df, x="Sugar", y="ChildObesity")
plt.title("Child Obesity vs Sugar Availability (2019)")
plt.show()

# %% [markdown]
# <img src="../assets/child_sugar.png" width=auto>

# %%
df = sugar_corr_df.dropna(subset=['Sugar','Stunting_U5'])

plt.figure(figsize=(6,4))
sns.regplot(data=df, x="Sugar", y="Stunting_U5")
plt.title("Sugar vs Stunting (Under 5) — 2019")
plt.show()

# %% [markdown]
# <img src="../assets/sugar_stunting.png" width=auto>

# %%
df = sugar_corr_df.dropna(subset=['Sugar','Wasting_U5'])

plt.figure(figsize=(6,4))
sns.regplot(data=df, x="Sugar", y="Wasting_U5")
plt.title("Sugar vs Wasting (Under 5) — 2019")
plt.show()

# %% [markdown]
# <img src="../assets/sugar_wasting.png" width=auto>

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=global_adult_obesity_trend, x='Year', y='Value_clean', label='Adult Obesity', marker='o')
sns.lineplot(data=global_child_obesity_trend, x='Year', y='Value_clean', label='Child Obesity', marker='x')
plt.title('Global Mean Obesity Rates (1990-2022)')
plt.xlabel('Year')
plt.ylabel('Mean Obesity Rate (%)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <img src="../assets/global mean obesity rates(1990-2022).png" width=auto>
